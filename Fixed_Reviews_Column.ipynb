# %%
from bs4 import BeautifulSoup
import requests

# %%
def generate_urls(type: str, offset: int=None):
    assert type in ['manga', 'anime'], 'Please provide `type` of either `manga` or `anime`'
    _url = f'https://myanimelist.net/top{type}.php'

    if offset is not None:
        assert offset % 50 == 0, 'Please provide offset in multiples of 50'
        _url = _url + f'?limit={offset}'

    res = requests.get(_url)
    soup = BeautifulSoup(res.text, 'html.parser')

    if type == 'anime':
        titles = soup.find_all('h3', class_='anime_ranking_h3')
    else:
        titles = soup.find_all('h3', class_='manga_h3')

    results = [
        {
            'title': title.a.contents,
            'url': title.a.get('href')
        } for title in titles
    ]

    continuation_token = soup.find_all('a', class_='next')
    if continuation_token is not None:
        if offset is None:
            offset = 50
        else:
            offset = offset + 50
    else:
        exit

    return offset, results

# %%
manga = []
offset = None
type = 'manga'
manga_count = 0

while manga_count < 200:  # Download n manga
    offset, _res = generate_urls(type=type, offset=offset)
    manga += _res
    print(f'{offset} {type} downloaded')
    manga_count += len(_res)
# Out:
# 50 manga downloaded
# 100 manga downloaded
# 150 manga downloaded
# 200 manga downloaded

# %%
manga[0]['url']
# Out:
# 'https://myanimelist.net/manga/2/Berserk'

# %%
import requests
from bs4 import BeautifulSoup

def download_reviews(url: str, offset: int=None):
    url = f'{url}/reviews'
    if offset is not None:
        url += f'?p={offset}'

    res = requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'html.parser')

    reviews = [review.get_text().strip('\n').lstrip() for review in soup.find_all('div', class_='text')]

    continuation_token = soup.find(attrs={'data-ga-click-type': 'review-more-reviews'})
    if continuation_token:
        if offset is None:
            offset = 2
        else:
            offset += 1

    return offset, reviews

# %%
# Iterate over manga items
for idx, item in enumerate(manga):
    offset = 1
    manga[idx]['reviews'] = []


    print(f'Downloading the first review for {item["title"]}')
    offset, reviews = download_reviews(item['url'], offset=offset)

    if reviews:
        manga[idx]['reviews'].append(reviews[0])


#total_reviews = sum(len(item['reviews']) for item in manga)
#print(f'Total reviews downloaded for all manga: {total_reviews}')
 #itll break if you download too many with a 405/https error
# Out:
# Downloading the first review for ['Berserk']
# Downloading the first review for ['JoJo no Kimyou na Bouken Part 7: Steel Ball Run']
# Downloading the first review for ['Vagabond']
# Downloading the first review for ['One Piece']
# Downloading the first review for ['Monster']
# Downloading the first review for ['Slam Dunk']
# Downloading the first review for ['Vinland Saga']
# Downloading the first review for ['Fullmetal Alchemist']
# Downloading the first review for ['Grand Blue']
# Downloading the first review for ['Oyasumi Punpun']
# Downloading the first review for ['Kingdom']
# Downloading the first review for ['Houseki no Kuni']
# Downloading the first review for ['Real']
# Downloading the first review for ['20th Century Boys']
# Downloading the first review for ['Ashita no Joe']
# Downloading the first review for ['Monogatari Series: First Season']
# Downloading the first review for ['Monogatari Series: Second Season']
# Downloading the first review for ['Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen']
# Downloading the first review for ['Umineko no Naku Koro ni Chiru - Episode 8: Twilight of the Golden Witch']
# Downloading the first review for ['Yotsuba to!']
# Downloading the first review for ['Mikkakan no Koufuku']
# Downloading the first review for ['GTO']
# Downloading the first review for ['3-gatsu no Lion']
# Downloading the first review for ['Monogatari Series: Final Season']
# Downloading the first review for ['Tian Guan Cifu']
# Downloading the first review for ['Koe no Katachi']
# Downloading the first review for ['Haikyuu!!']
# Downloading the first review for ['Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e']
# Downloading the first review for ['Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e: 2-nensei-hen']
# Downloading the first review for ['Kaze no Tani no Nausicaä']
# Downloading the first review for ['Monogatari Series: Monster Season']
# Downloading the first review for ['Ookami to Koushinryou']
# Downloading the first review for ['Akatsuki no Yona']
# Downloading the first review for ['Mushoku Tensei: Isekai Ittara Honki Dasu']
# Downloading the first review for ['86']
# Downloading the first review for ['Nana']
# Downloading the first review for ['Re:Zero kara Hajimeru Isekai Seikatsu']
# Downloading the first review for ['Sousou no Frieren']
# Downloading the first review for ['Jumyou wo Kaitotte Moratta. Ichinen ni Tsuki, Ichimanen de.']
# Downloading the first review for ['Uchuu Kyoudai']
# Downloading the first review for ['Kokou no Hito']
# Downloading the first review for ['Yahari Ore no Seishun Love Comedy wa Machigatteiru.']
# Downloading the first review for ['Kino no Tabi: The Beautiful World']
# Downloading the first review for ['Made in Abyss']
# Downloading the first review for ['Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen']
# Downloading the first review for ['One Punch-Man']
# Downloading the first review for ['Hajime no Ippo']
# Downloading the first review for ['Hunter x Hunter']
# Downloading the first review for ['Omniscient Reader']
# Downloading the first review for ['Mushishi']
# Downloading the first review for ['Shoujo Shuumatsu Ryokou']
# Downloading the first review for ['Chainsaw Man']
# Downloading the first review for ['Utsuro no Hako to Zero no Maria']
# Downloading the first review for ['Shinyaku Toaru Majutsu no Index']
# Downloading the first review for ['Koten-bu Series']
# Downloading the first review for ['Beck']
# Downloading the first review for ['Death Note']
# Downloading the first review for ['Zaregoto Series']
# Downloading the first review for ['Kono Oto Tomare!']
# Downloading the first review for ['Yokohama Kaidashi Kikou']
# Downloading the first review for ['Dorohedoro']
# Downloading the first review for ['Akira']
# Downloading the first review for ['Kozure Ookami']
# Downloading the first review for ['Natsume Yuujinchou']
# Downloading the first review for ['Solo Leveling']
# Downloading the first review for ['Bungou Stray Dogs: Beast']
# Downloading the first review for ['The Horizon']
# Downloading the first review for ['Yagate Kimi ni Naru']
# Downloading the first review for ['Sayonara Eri']
# Downloading the first review for ['Tian Guan Cifu']
# Downloading the first review for ['Golden Kamuy']
# Downloading the first review for ['Kimi no Suizou wo Tabetai']
# Downloading the first review for ['Veil']
# Downloading the first review for ['Aria']
# Downloading the first review for ['Fata Morgana no Yakata: Anata no Genten ni Itaru Monogatari']
# Downloading the first review for ['Seishun Buta Yarou Series']
# Downloading the first review for ['Overlord']
# Downloading the first review for ['Kusuriya no Hitorigoto']
# Downloading the first review for ['ReLIFE']
# Downloading the first review for ['Pluto']
# Downloading the first review for ['Hi no Tori (1967)']
# Downloading the first review for ['Umineko no Naku Koro ni Chiru - Episode 7: Requiem of the Golden Witch']
# Downloading the first review for ['Violet Evergarden']
# Downloading the first review for ['Blue Period']
# Downloading the first review for ['Gintama']
# Downloading the first review for ['Mo Dao Zu Shi']
# Downloading the first review for ['Souyaku Toaru Majutsu no Index']
# Downloading the first review for ['Kidou Senshi Gundam: The Origin']
# Downloading the first review for ['Banana Fish']
# Downloading the first review for ['Kono Subarashii Sekai ni Shukufuku wo!']
# Downloading the first review for ['Mob Psycho 100']
# Downloading the first review for ['Tobaku Datenroku Kaiji: One Poker-hen']
# Downloading the first review for ['Dungeon Meshi']
# Downloading the first review for ['Tongari Boushi no Atelier']
# Downloading the first review for ['Umarekawattemo Mata, Watashi to Kekkon shitekuremasu ka']
# Downloading the first review for ['Suzumiya Haruhi Series']
# Downloading the first review for ['Kaoru Hana wa Rin to Saku']
# Downloading the first review for ['Ao Ashi']
# Downloading the first review for ['Ginga Eiyuu Densetsu']
# Downloading the first review for ['Shigatsu wa Kimi no Uso']
# Downloading the first review for ['Umineko no Naku Koro ni']
# Downloading the first review for ['Shuumatsu Nani Shitemasu ka? Isogashii desu ka? Sukutte Moratte Ii desu ka?']
# Downloading the first review for ['Skip to Loafer']
# Downloading the first review for ['Shinseiki Evangelion']
# Downloading the first review for ['Kusuriya no Hitorigoto']
# Downloading the first review for ['Monogatari Series: Off Season']
# Downloading the first review for ['Wind Breaker']
# Downloading the first review for ['JoJo no Kimyou na Bouken Part 4: Diamond wa Kudakenai']
# Downloading the first review for ['Pandora Hearts']
# Downloading the first review for ['Chihayafuru']
# Downloading the first review for ['Rurouni Kenshin: Meiji Kenkaku Romantan']
# Downloading the first review for ['Skip Beat!']
# Downloading the first review for ['One Outs']
# Downloading the first review for ['Otoyomegatari']
# Downloading the first review for ['Steins;Gate']
# Downloading the first review for ['Diamond no Ace Act II']
# Downloading the first review for ['Jibaku Shounen Hanako-kun']
# Downloading the first review for ['Medalist']
# Downloading the first review for ['Hirayasumi']
# Downloading the first review for ['Baccano!']
# Downloading the first review for ['Umineko no Naku Koro ni Chiru']
# Downloading the first review for ['Blue Giant']
# Downloading the first review for ['Katanagatari']
# Downloading the first review for ['Shingeki no Kyojin']
# Downloading the first review for ['Umineko no Naku Koro ni Chiru - Episode 5: End of the Golden Witch']
# Downloading the first review for ['Sakamichi no Apollon']
# Downloading the first review for ['Kamisama Hajimemashita']
# Downloading the first review for ['"Oshi no Ko"']
# Downloading the first review for ['Bakemonogatari']
# Downloading the first review for ['Yagate Kimi ni Naru: Saeki Sayaka ni Tsuite']
# Downloading the first review for ['Spy x Family']
# Downloading the first review for ['Fruits Basket']
# Downloading the first review for ['Kara no Kyoukai: The Garden of Sinners']
# Downloading the first review for ['Ping Pong']
# Downloading the first review for ['Usogui']
# Downloading the first review for ['Tokyo Ghoul']
# Downloading the first review for ['The Fable']
# Downloading the first review for ['Sasaki to Miyano']
# Downloading the first review for ['Fate/Zero']
# Downloading the first review for ['Jujutsu Kaisen']
# Downloading the first review for ['Blue Lock']
# Downloading the first review for ['Given']
# Downloading the first review for ['Kakukaku Shikajika']
# Downloading the first review for ['Mahoutsukai no Yoru']
# Downloading the first review for ['Glass no Kamen']
# Downloading the first review for ['Kyou kara Ore wa!!']
# Downloading the first review for ['Rainbow: Nisha Rokubou no Shichinin']
# Downloading the first review for ['Watashitachi no Shiawase na Jikan']
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-6-1466364eac1f> in <cell line: 2>()
#       6
#       7     print(f'Downloading the first review for {item["title"]}')
# ----> 8     offset, reviews = download_reviews(item['url'], offset=offset)
#       9
#      10     if reviews:
#
# <ipython-input-5-220c3cd10320> in download_reviews(url, offset)
#       8
#       9     res = requests.get(url)
# ---> 10     res.raise_for_status()
#      11     soup = BeautifulSoup(res.text, 'html.parser')
#      12
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 405 Client Error: Not Allowed for url: https://myanimelist.net/manga/11734/Watashitachi_no_Shiawase_na_Jikan/reviews?p=1

# %%
manga[0].keys()
# Out:
# dict_keys(['title', 'url', 'reviews'])

# %%
len(manga[5]['reviews'])
# Out:
# 1

# %%
import pandas as pd
data = pd.DataFrame(manga)
data
# Out:
#                                                  title  \
# 0                                            [Berserk]
# 1    [JoJo no Kimyou na Bouken Part 7: Steel Ball Run]
# 2                                           [Vagabond]
# 3                                          [One Piece]
# 4                                            [Monster]
# ..                                                 ...
# 195                               [Seasons of Blossom]
# 196                                   [Tomodachi Game]
# 197                                       [Here U Are]
# 198                         [Gekkan Shoujo Nozaki-kun]
# 199                                  [No Game No Life]
#
#                                                    url  \
# 0              https://myanimelist.net/manga/2/Berserk
# 1    https://myanimelist.net/manga/1706/JoJo_no_Kim...
# 2           https://myanimelist.net/manga/656/Vagabond
# 3           https://myanimelist.net/manga/13/One_Piece
# 4              https://myanimelist.net/manga/1/Monster
# ..                                                 ...
# 195  https://myanimelist.net/manga/145539/Seasons_o...
# 196  https://myanimelist.net/manga/62795/Tomodachi_...
# 197    https://myanimelist.net/manga/119072/Here_U_Are
# 198  https://myanimelist.net/manga/29211/Gekkan_Sho...
# 199  https://myanimelist.net/manga/48399/No_Game_No...
#
#                                                reviews
# 0    [Story - 9.38\n\r\nThe first three volumes may...
# 1    [Serving as a soft reset for Jojo's Bizarre Ad...
# 2    [Some seinen manga, I believe, take the meanin...
# 3    [Frequently categorized with both Bleach and N...
# 4    [I rarely give tens to mangas. But this one ju...
# ..                                                 ...
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
# [200 rows x 3 columns]

# %%
data.drop(data.tail(50).index,
        inplace = True)

# %%
data
# Out:
#                                                  title  \
# 0                                            [Berserk]
# 1    [JoJo no Kimyou na Bouken Part 7: Steel Ball Run]
# 2                                           [Vagabond]
# 3                                          [One Piece]
# 4                                            [Monster]
# ..                                                 ...
# 140                                        [Blue Lock]
# 141                                            [Given]
# 142                               [Kakukaku Shikajika]
# 143                              [Mahoutsukai no Yoru]
# 144                                   [Glass no Kamen]
#
#                                                    url  \
# 0              https://myanimelist.net/manga/2/Berserk
# 1    https://myanimelist.net/manga/1706/JoJo_no_Kim...
# 2           https://myanimelist.net/manga/656/Vagabond
# 3           https://myanimelist.net/manga/13/One_Piece
# 4              https://myanimelist.net/manga/1/Monster
# ..                                                 ...
# 140     https://myanimelist.net/manga/114745/Blue_Lock
# 141          https://myanimelist.net/manga/79085/Given
# 142  https://myanimelist.net/manga/44307/Kakukaku_S...
# 143  https://myanimelist.net/manga/26027/Mahoutsuka...
# 144  https://myanimelist.net/manga/1469/Glass_no_Kamen
#
#                                                reviews
# 0    [Story - 9.38\n\r\nThe first three volumes may...
# 1    [Serving as a soft reset for Jojo's Bizarre Ad...
# 2    [Some seinen manga, I believe, take the meanin...
# 3    [Frequently categorized with both Bleach and N...
# 4    [I rarely give tens to mangas. But this one ju...
# ..                                                 ...
# 140  [Honestly, out of all the sports anime I have ...
# 141  [Given is a truly amazing story that features ...
# 142  [If you have read or watched Bakuman., you mig...
# 143  [This is a review of the visual novel of Witch...
# 144  [Glass mask is one of the best shoujo manga ou...
#
# [145 rows x 3 columns]

# %%
data.to_csv('manga_reviews.csv')
